# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
heart_data= pd.read_csv('heart.csv')

# %%
heart_data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  RestingECG  \
# 0   40    0              0        140          289           0
# 1   49    1              1        160          180           0
# 2   37    0              0        130          283           1
# 3   48    1              2        138          214           0
# 4   54    0              1        150          195           0
#
#    ExerciseAngina  HeartDisease
# 0               0             0
# 1               0             1
# 2               0             0
# 3               1             1
# 4               0             0

# %%
heart_data.tail()
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  RestingECG  \
# 12847   45    0              3        110          264           0
# 12848   68    0              2        144          193           0
# 12849   57    0              2        130          131           0
# 12850   57    1              0        130          236           2
# 12851   38    0              1        138          175           0
#
#        ExerciseAngina  HeartDisease
# 12847               0             1
# 12848               0             1
# 12849               1             1
# 12850               0             1
# 12851               0             0

# %%
heart_data.shape
# Out:
# (12852, 8)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12852 entries, 0 to 12851
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             12852 non-null  int64
#  1   Sex             12852 non-null  int64
#  2   ChestPainType   12852 non-null  int64
#  3   RestingBP       12852 non-null  int64
#  4   Cholesterol     12852 non-null  int64
#  5   RestingECG      12852 non-null  int64
#  6   ExerciseAngina  12852 non-null  int64
#  7   HeartDisease    12852 non-null  int64
# dtypes: int64(8)
# memory usage: 803.4 KB

# %%
heart_data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# RestingECG        0
# ExerciseAngina    0
# HeartDisease      0
# dtype: int64

# %%
heart_data.describe()
# Out:
#                 Age           Sex  ChestPainType     RestingBP   Cholesterol  \
# count  12852.000000  12852.000000   12852.000000  12852.000000  12852.000000
# mean      53.510815      0.210240       1.452070    132.396514    198.799564
# std        9.427762      0.407495       0.851401     18.504787    109.328804
# min       28.000000      0.000000       0.000000      0.000000      0.000000
# 25%       47.000000      0.000000       1.000000    120.000000    173.000000
# 50%       54.000000      0.000000       2.000000    130.000000    223.000000
# 75%       60.000000      0.000000       2.000000    140.000000    267.000000
# max       77.000000      1.000000       3.000000    200.000000    603.000000
#
#          RestingECG  ExerciseAngina  HeartDisease
# count  12852.000000    12852.000000  12852.000000
# mean       0.603486        0.404139      0.553377
# std        0.805560        0.490744      0.497162
# min        0.000000        0.000000      0.000000
# 25%        0.000000        0.000000      0.000000
# 50%        0.000000        0.000000      1.000000
# 75%        1.000000        1.000000      1.000000
# max        2.000000        1.000000      1.000000

# %%
heart_data['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    7112
# 0    5740
# Name: count, dtype: int64

# %%
X=heart_data.drop(columns='HeartDisease',axis=1)
Y=heart_data['HeartDisease']

# %%
print(X)
# Out:
#        Age  Sex  ChestPainType  RestingBP  Cholesterol  RestingECG  \
# 0       40    0              0        140          289           0
# 1       49    1              1        160          180           0
# 2       37    0              0        130          283           1
# 3       48    1              2        138          214           0
# 4       54    0              1        150          195           0
# ...    ...  ...            ...        ...          ...         ...
# 12847   45    0              3        110          264           0
# 12848   68    0              2        144          193           0
# 12849   57    0              2        130          131           0
# 12850   57    1              0        130          236           2
# 12851   38    0              1        138          175           0
#
#        ExerciseAngina
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
# ...               ...
# 12847               0
# 12848               0
# 12849               1
# 12850               0
# 12851               0
#
# [12852 rows x 7 columns]

# %%
print(Y)
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 12847    1
# 12848    1
# 12849    1
# 12850    1
# 12851    0
# Name: HeartDisease, Length: 12852, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (12852, 7) (10281, 7) (2571, 7)

# %%
model= LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\MuhammadZarnain\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction=model.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction,Y_train)

# %%
print("Accuracy on train data: ",training_data_accuracy )
# Out:
# Accuracy on train data:  0.808676198813345

# %%
X_train_prediction=model.predict(X_test)
training_data_accuracy= accuracy_score(X_train_prediction,Y_test)

# %%
print("Accuracy on train data: ",training_data_accuracy )
# Out:
# Accuracy on train data:  0.8063010501750292

# %%
input_data=(60,1,3,240,254,2,1)
input_data_array= np.asarray(input_data)
input_data_reshape = input_data_array.reshape(1,-1)
prediction= model.predict(input_data_reshape)
print(prediction)
if(prediction[0]==0):
    print('the person doesnot have heart disease')
else:
    print('The person has heart disease')
# Out:
# [1]
# The person has heart disease
# C:\Users\MuhammadZarnain\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(model, open("heart_predict.pkl","wb"))
